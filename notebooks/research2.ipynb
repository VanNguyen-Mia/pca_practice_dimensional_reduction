# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np

# %% [markdown]
# ### Step 1: Read the dataset

# %%
# 1. Read dataset
df = pd.read_csv("../dataset/Breast_GSE45827.csv")

# %%
# Check the shape of the data
df.shape
# Out:
# (151, 54677)

# %%
# Change to dataframe
df = pd.DataFrame(df)
df.head()
# Out:
#    samples   type  1007_s_at   1053_at    117_at    121_at  1255_g_at  \
# 0       84  basal   9.850040  8.097927  6.424728  7.353027   3.029122
# 1       85  basal   9.861357  8.212222  7.062593  7.685578   3.149468
# 2       87  basal  10.103478  8.936137  5.735970  7.687822   3.125931
# 3       90  basal   9.756875  7.357148  6.479183  6.986624   3.181638
# 4       91  basal   9.408330  7.746404  6.693980  7.333426   3.169923
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  6.880079  4.963740  4.408328  ...             12.229711
# 1  7.542283  5.129607  4.584418  ...             12.178531
# 2  6.562369  4.813449  4.425195  ...             12.125108
# 3  7.802344  5.490982  4.567956  ...             12.111235
# 4  7.610457  5.372469  4.424426  ...             12.173642
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0             11.852955            13.658701            13.477698
# ...

# %% [markdown]
# ### Step 2: Preprocess data

# %%
df = df.dropna()
df.shape
# Out:
# (151, 54677)

# %% [markdown]
# ### Step 3: Apply PCA

# %%
# Extracting features
features = df.drop(columns=['samples', 'type'])
features.head()
# Out:
#    1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0   9.850040  8.097927  6.424728  7.353027   3.029122  6.880079  4.963740
# 1   9.861357  8.212222  7.062593  7.685578   3.149468  7.542283  5.129607
# 2  10.103478  8.936137  5.735970  7.687822   3.125931  6.562369  4.813449
# 3   9.756875  7.357148  6.479183  6.986624   3.181638  7.802344  5.490982
# 4   9.408330  7.746404  6.693980  7.333426   3.169923  7.610457  5.372469
#
#     1320_at  1405_i_at   1431_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  4.408328   8.870780  3.278896  ...             12.229711
# 1  4.584418   7.767646  3.589636  ...             12.178531
# 2  4.425195   9.417956  3.552253  ...             12.125108
# 3  4.567956   9.022345  3.312473  ...             12.111235
# 4  4.424426   9.400056  3.368243  ...             12.173642
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0             11.852955            13.658701            13.477698
# ...

# %%
# Standardising features
features_scaled = StandardScaler().fit_transform(features)

# %%
# Check whether the normalised data has a mean of zero and a standard deviation of one
np.mean(features_scaled), np.std(features_scaled)
# Out:
# (-4.003724363721795e-18, 0.9999999999999997)

# %%
# Convert normalized features into a tabular format
features_cols = ['feature' + str(i) for i in range(features_scaled.shape[1])]

# %%
features_scaled = pd.DataFrame(features_scaled, columns=features_cols)
features_scaled.tail()
# Out:
#      feature0  feature1  feature2  feature3  feature4  feature5  feature6  \
# 146  0.087890 -0.422517  0.969541 -0.966740  0.270313  0.789420  0.425795
# 147  0.968212  1.112570 -0.494421  1.256556  0.538607  0.090147  1.987368
# 148  1.125590 -0.640564  0.124128  0.915745  0.136999  1.967392  1.702215
# 149  0.172542 -0.151619 -0.404831  1.476030  1.255798 -0.065296 -0.267127
# 150  1.646875 -0.358761 -0.518757  0.167826 -0.011569  0.754178  0.110699
#
#      feature7  feature8  feature9  ...  feature54665  feature54666  \
# 146 -0.706087  0.138680  0.468316  ...      0.878921      0.810411
# 147  1.561670  0.280267 -0.347814  ...      0.516424      0.419347
# 148 -0.314725 -0.160818 -0.382883  ...     -0.324020     -0.440169
# 149  1.215861 -0.257451  0.513301  ...     -0.118799     -0.259585
# 150 -0.833040 -0.003226  2.032668  ...     -0.735694     -0.934517
#
#      feature54667  feature54668  feature54669  feature54670  feature54671  \
# ...

# %%
# n_components = 2
pca = PCA(0.95)
pca_temp = pca.fit_transform(features_scaled)

# %%
pca.n_components_
# Out:
# 126

# %%
# Create a dataframe with the transformed components
df_pca = pd.DataFrame(data=pca_temp)

# %%
df_pca.tail()
# Out:
#            0          1          2          3          4          5    \
# 146  68.689831  44.095194  42.092571  47.268355 -23.024043 -76.845281
# 147  15.107800  19.759284  44.375256 -39.147452 -25.656155 -52.420656
# 148  50.520502  -2.911368  23.302824 -40.261843 -15.359798 -37.276442
# 149  68.928212  27.380156   6.417308 -85.352301   4.986715  10.912455
# 150  61.932694  24.381701  26.753062 -16.090544 -38.147851 -36.376049
#
#            6          7          8          9    ...       116        117  \
# 146  66.221048 -17.962789  44.719130 -38.269264  ...  7.993429  15.878066
# 147 -15.314269  18.030233  29.792262 -29.653889  ... -2.516404  -1.349494
# 148  16.118697  14.193622  29.071574 -13.498306  ... -6.457588  -5.822463
# 149  -4.822358   5.516292  12.280003  13.303679  ... -7.559661  27.140352
# 150  26.231004  -2.576721  -2.437985  17.896003  ... -4.321901  -2.340584
#
#            118        119        120        121        122        123  \
# ...

# %%
# Print explained variance ratio (*100 for the percentage of the information held)
pca.explained_variance_ratio_
# Out:
# array([0.1118076 , 0.10185951, 0.05222938, 0.03383956, 0.03293161,
#        0.02855846, 0.02210805, 0.01850792, 0.01529937, 0.01288263,
#        0.01236123, 0.01093918, 0.01036157, 0.00999003, 0.0091483 ,
#        0.00883893, 0.00859201, 0.00846616, 0.008167  , 0.00813459,
#        0.00787938, 0.00751295, 0.00743386, 0.00722776, 0.00700703,
#        0.00693969, 0.00669325, 0.00652038, 0.00647261, 0.00633913,
#        0.00617316, 0.00612615, 0.00589779, 0.00583701, 0.00578903,
#        0.00566635, 0.00552205, 0.00542354, 0.00539455, 0.00536862,
#        0.00522269, 0.00517787, 0.00508097, 0.00503152, 0.0049595 ,
#        0.00486846, 0.00482924, 0.00475971, 0.00470101, 0.00464672,
#        0.0045892 , 0.00455521, 0.0044841 , 0.00445768, 0.00437698,
#        0.00436903, 0.00434439, 0.00431034, 0.00422007, 0.00416602,
#        0.00414235, 0.00412603, 0.00404397, 0.00399734, 0.00396313,
#        0.00389302, 0.00387666, 0.00384836, 0.00380291, 0.00376418,
# ...

# %%
set(df["type"])
# Out:
# {'HER', 'basal', 'cell_line', 'luminal_A', 'luminal_B', 'normal'}

# %%
import itertools

# %%
# Plot the visualization
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of Breast Cancer Dataset",fontsize=20)
targets = ['HER', 'basal', 'cell_line', 'luminal_A', 'luminal_B', 'normal']
colors = ['r', 'g', 'b', 'y', 'c', 'm']

# Create an iterator that will cycle through the color list
color_cycle = itertools.cycle(colors)

for target, color in zip(targets,colors):
    indicesToKeep = df['type'] == target
    plt.scatter(df_pca.loc[indicesToKeep, 4]
               , df_pca.loc[indicesToKeep, 5], c = next(color_cycle), s = 50)

plt.legend(targets,prop={'size': 15})

# %%
images = os.path.join("./images")
os.makedirs(images, exist_ok=True)
pca_image_path = os.path.join(images, "pca_scatter_plot.png")
plt.savefig(pca_image_path)
